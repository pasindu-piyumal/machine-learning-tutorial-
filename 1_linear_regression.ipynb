# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_excel("price.xlsx")
df
# Out:
#    Area   Price
# 0  2400  500000
# 1  3000  550000
# 2  3600  610000
# 3  4200  670000
# 4  4800  730000

# %%
# %matplotlib inline
plt.xlabel("Area")
plt.ylabel("Price")
plt.scatter(df.Area, df.Price, color='red', marker='+')

# %%
regression = linear_model.LinearRegression()
regression.fit(df[["Area"]], df.Price)
# Out:
# LinearRegression()

# %%
regression.predict([[3300]])
# Out:
# C:\Users\USER\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([583000.])

# %%
regression.coef_
# Out:
# array([96.66666667])

# %%
regression.intercept_
# Out:
# np.float64(264000.00000000006)

# %%
96.66666667*3300 + 264000.00000000006
# Out:
# 583000.0000110001

# %%
# %matplotlib inline
plt.xlabel("area", fontsize=20)
plt.ylabel("price", fontsize=20)
plt.scatter(df.Area, df.Price, color="red")
plt.plot(df.Area, regression.predict(df[["Area"]]), color="blue")

# %%
regression.predict([[5000]])
# Out:
# C:\Users\USER\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([747333.33333333])

# %%
df2 = pd.read_excel("area.xlsx")
df2.head()
# Out:
#    Area
# 0  2000
# 1  2300
# 2  2640
# 3  3040
# 4  3240

# %%
p = regression.predict(df2)

# %%
df2["Price"] = p

# %%
df2
# Out:
#    Area          Price
# 0  2000  457333.333333
# 1  2300  486333.333333
# 2  2640  519200.000000
# 3  3040  557866.666667
# 4  3240  577200.000000
# 5  3500  602333.333333
# 6  3750  626500.000000
# 7  4100  660333.333333
# 8  4210  670966.666667
# 9  5000  747333.333333

# %%
df2.to_csv("prediction.csv", index=False)
