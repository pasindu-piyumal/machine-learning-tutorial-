# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_excel("price.xlsx")
df
# Out:
#    Area   Price
# 0  2400  500000
# 1  3000  550000
# 2  3600  610000
# 3  4200  670000
# 4  4800  730000
